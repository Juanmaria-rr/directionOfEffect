# %%
from pyspark.sql import SparkSession, Window
import pyspark.sql.functions as F

spark = SparkSession.builder.getOrCreate()
coloc=spark.read.parquet("gs://genetics-portal-dev-data/22.09.1/outputs/v2d_coloc").filter(F.col("right_type") != "gwas")

# %%
### load ot_genetics_portal 

var_filter_lof = [
    ### High impact variants https://www.ensembl.org/info/genome/variation/prediction/predicted_data.html
    "SO_0001589",  ## frameshit_variant
    "SO_0001587",  ## stop_gained
    "SO_0001574",  ## splice_acceptor_variant
    "SO_0001575",  ## splice_donor_variant
    "SO_0002012",  ## start_lost
    "SO_0001578",  ## stop_lost
    "SO_0001893",  ## transcript_ablation
]

gof = ["SO_0002053"]
lof = ["SO_0002054"]

evd = (
    spark.read.parquet(
        "gs://open-targets-data-releases/23.06/output/etl/parquet/evidence/sourceId=ot_genetics_portal"
    )
    .selectExpr(
        "studyId",
        "variantId as locusId",
        "targetId",
        "diseaseId",
        "oddsRatio",
        "beta",
        "variantFunctionalConsequenceFromQtlId",
        "variantFunctionalConsequenceId"
       # "score",
    )
    
    .withColumn(
        "effect",
        F.when((F.col("beta") > 0) | (F.col("oddsRatio") > 1), "risk")
        .when((F.col("beta") < 0) | (F.col("oddsRatio") < 1), "protective")
        .otherwise("unknown"),  # 23% of evidence has unknown direction of effect
    )
    .withColumn("functionalVar",F.when(F.col("variantFunctionalConsequenceId").isin(var_filter_lof), F.lit("lof")).otherwise("noInfo"))
    .persist()
)

# %%
### load v2d for exploring

v2d=spark.read.parquet("gs://genetics-portal-dev-data/22.09.1/outputs/v2d")
v2d_gwas=v2d.select(
        F.concat_ws("_", "lead_chrom", "lead_pos", "lead_ref", "lead_alt").alias(
            "left_locus_id"
        ),
        F.col("beta"),
        F.col("odds_ratio"),
        F.col("study_id"),
        F.col("trait_reported"),
        F.col("trait_efos"),
        F.col("n_cases"),
        F.col("n_initial"))

# %%
### load QTL tissues mapped to therapy areas 
onto_samples=spark.read.csv("hdfs:///mydata/updated/mappedSQLtissuesGTP3_5.csv",header=True)

# %%
onto_samples.show()
# Out:
# +--------------------+--------------------+--------------------+----+----+
# |            original|             curated|  curated_simplified| _c3| _c4|
# +--------------------+--------------------+--------------------+----+----+
# |Whole_Blood - EFO...|Whole_Blood - EFO...|Whole_Blood - EFO...|null|null|
# |VAGINA - OTAR_000...|Vagina - OTAR_000...|Vagina - OTAR_000...|null|null|
# |Vagina - OTAR_000...|Vagina - OTAR_000...|Vagina - OTAR_000...|null|null|
# |UTERUS - OTAR_000...|Uterus - OTAR_000...|Uterus - OTAR_000...|null|null|
# |Uterus - OTAR_000...|Uterus - OTAR_000...|Uterus - OTAR_000...|null|null|
# |UBERON_0001969 - ...|UBERON_0001969 - ...|UBERON_0001969 - ...|null|null|
# |UBERON_0000178 - ...|UBERON_0000178 - ...|UBERON_0000178 - ...|null|null|
# |TREG_NAIVE - EFO_...|TREG_NAIVE - EFO_...|TREG_NAIVE - EFO_...|null|null|
# |TREG_MEMORY - EFO...|TREG_MEMORY - EFO...|TREG_MEMORY - EFO...|null|null|
# |TRANSVERSE_COLON ...|TRANSVERSE_COLON ...|TRANSVERSE_COLON ...|null|null|
# |THYROID - EFO_000...|THYROID - EFO_000...|Thyroid - EFO_000...|null|null|
# |Thyroid - EFO_000...|Thyroid - EFO_000...|Thyroid - EFO_000...|null|null|
# |TH2_MEMORY - EFO_...|TH2_MEMORY - EFO_...|TH2_MEMORY - EFO_...|null|null|
# |TH17_MEMORY - EFO...|TH17_MEMORY - EFO...|TH17_MEMORY - EFO...|null|null|
# |TH1-17_MEMORY - E...|TH1-17_MEMORY - E...|TH1-17_MEMORY - E...|null|null|
# |TH1_MEMORY - EFO_...|TH1_MEMORY - EFO_...|TH1_MEMORY - EFO_...|null|null|
# |TFH_MEMORY - EFO_...|TFH_MEMORY - EFO_...|TFH_MEMORY - EFO_...|null|null|
# |TESTIS - OTAR_000...|TESTIS - OTAR_000...|Testis - OTAR_000...|null|null|
# |Testis - OTAR_000...|Testis - OTAR_000...|Testis - OTAR_000...|null|null|
# |T-CELL_CD8 - EFO_...|T-CELL_CD8 - EFO_...|T-CELL_CD8 - EFO_...|null|null|
# +--------------------+--------------------+--------------------+----+----+
# only showing top 20 rows

# %%
### take ontology of samples 
samplesOnto=onto_samples.withColumn("right_bio_feature", F.split(F.col("original"), " - ").getItem(0)
).withColumn("therapyArea", F.split(F.col("curated_simplified"), " - ").getItem(2)
).withColumn("EFO", F.split(F.col("curated_simplified"), " - ").getItem(1)
).drop("curated_simplified","original","curated","_c3","_c4")

# %%
samplesOnto.show(200)
# Out:
# [Stage 6:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+------------+
# |   right_bio_feature|         therapyArea|         EFO|
# +--------------------+--------------------+------------+
# |         Whole_Blood| hematologic disease| EFO_0005803|
# |              VAGINA|reproductive syst...|OTAR_0000017|
# |              Vagina|reproductive syst...|OTAR_0000017|
# |              UTERUS|reproductive syst...|OTAR_0000017|
# |              Uterus|reproductive syst...|OTAR_0000017|
# |      UBERON_0001969| hematologic disease| EFO_0005803|
# |      UBERON_0000178| hematologic disease| EFO_0005803|
# |          TREG_NAIVE|immune system dis...| EFO_0000540|
# |         TREG_MEMORY|immune system dis...| EFO_0000540|
# |    TRANSVERSE_COLON|gastrointestinal ...| EFO_0010282|
# |             THYROID|endocrine system ...| EFO_0001379|
# |             Thyroid|endocrine system ...| EFO_0001379|
# |          TH2_MEMORY|immune system dis...| EFO_0000540|
# |         TH17_MEMORY|immune system dis...| EFO_0000540|
# |       TH1-17_MEMORY|immune system dis...| EFO_0000540|
# |          TH1_MEMORY|immune system dis...| EFO_0000540|
# |          TFH_MEMORY|immune system dis...| EFO_0000540|
# |              TESTIS|reproductive syst...|OTAR_0000017|
# |              Testis|reproductive syst...|OTAR_0000017|
# |          T-CELL_CD8|immune system dis...| EFO_0000540|
# |          T-CELL_CD4|immune system dis...| EFO_0000540|
# |              T-CELL|immune system dis...| EFO_0000540|
# |      SYNOVIUM_NAIVE|musculoskeletal o...|OTAR_0000006|
# |    SUBSTANTIA_NIGRA|nervous system di...| EFO_0000618|
# |             STOMACH|gastrointestinal ...| EFO_0010282|
# |             Stomach|gastrointestinal ...| EFO_0010282|
# |              Spleen|immune system dis...| EFO_0000540|
# |              SPLEEN|immune system dis...| EFO_0000540|
# |Small_Intestine_T...|gastrointestinal ...| EFO_0010282|
# |     SMALL_INTESTINE|gastrointestinal ...| EFO_0010282|
# |Skin_Sun_Exposed_...|integumentary sys...| EFO_0010285|
# |    SKIN_SUN_EXPOSED|integumentary sys...| EFO_0010285|
# |Skin_Not_Sun_Expo...|integumentary sys...| EFO_0010285|
# |SKIN_NOT_SUN_EXPOSED|integumentary sys...| EFO_0010285|
# |                SKIN|integumentary sys...| EFO_0010285|
# |      SENSORY_NEURON|nervous system di...| EFO_0000618|
# |              RECTUM|gastrointestinal ...| EFO_0010282|
# |             PUTAMEN|nervous system di...| EFO_0000618|
# |            Prostate|reproductive syst...|OTAR_0000017|
# |            PROSTATE|reproductive syst...|OTAR_0000017|
# |            PLATELET| hematologic disease| EFO_0005803|
# |      PLACENTA_NAIVE|pregnancy or peri...|OTAR_0000014|
# |           Pituitary|endocrine system ...| EFO_0001379|
# |           PITUITARY|endocrine system ...| EFO_0001379|
# |    PANCREATIC_ISLET|    pancreas disease| EFO_0009605|
# |            Pancreas|    pancreas disease| EFO_0009605|
# |            PANCREAS|    pancreas disease| EFO_0009605|
# |               OVARY|reproductive syst...|OTAR_0000017|
# |               Ovary|reproductive syst...|OTAR_0000017|
# |       NK-CELL_NAIVE|immune system dis...| EFO_0000540|
# |     NEUTROPHIL_CD16|immune system dis...| EFO_0000540|
# |     NEUTROPHIL_CD15|immune system dis...| EFO_0000540|
# |          NEUTROPHIL|immune system dis...| EFO_0000540|
# |        Nerve_Tibial|nervous system di...| EFO_0000618|
# |        NERVE_TIBIAL|nervous system di...| EFO_0000618|
# |     Muscle_Skeletal|musculoskeletal o...|OTAR_0000006|
# |        MUSCLE_NAIVE|musculoskeletal o...|OTAR_0000006|
# |              MUSCLE|musculoskeletal o...|OTAR_0000006|
# |       MONOCYTE_R848|immune system dis...| EFO_0000540|
# |   MONOCYTE_PAM3CSK4|immune system dis...| EFO_0000540|
# |      MONOCYTE_NAIVE|immune system dis...| EFO_0000540|
# |      MONOCYTE_LPS24|immune system dis...| EFO_0000540|
# |       MONOCYTE_LPS2|immune system dis...| EFO_0000540|
# |        MONOCYTE_LPS|immune system dis...| EFO_0000540|
# |      MONOCYTE_IFN24|immune system dis...| EFO_0000540|
# |        MONOCYTE_IAV|immune system dis...| EFO_0000540|
# | MONOCYTE_CD16_NAIVE|immune system dis...| EFO_0000540|
# |       MONOCYTE_CD14|immune system dis...| EFO_0000540|
# |            MONOCYTE|immune system dis...| EFO_0000540|
# |MINOR_SALIVARY_GLAND|gastrointestinal ...| EFO_0010282|
# |Minor_Salivary_Gland|gastrointestinal ...| EFO_0010282|
# |     MICROGLIA_NAIVE|immune system dis...| EFO_0000540|
# |MACROPHAGE_SALMON...|immune system dis...| EFO_0000540|
# |    MACROPHAGE_NAIVE|immune system dis...| EFO_0000540|
# | MACROPHAGE_LISTERIA|immune system dis...| EFO_0000540|
# |MACROPHAGE_IFNG+S...|immune system dis...| EFO_0000540|
# |     MACROPHAGE_IFNG|immune system dis...| EFO_0000540|
# |                LUNG|respiratory or th...|OTAR_0000010|
# |                Lung|respiratory or th...|OTAR_0000010|
# |LOW_GRADE_CARTILA...|musculoskeletal o...|OTAR_0000006|
# |               LIVER|gastrointestinal ...| EFO_0010282|
# |               Liver|gastrointestinal ...| EFO_0010282|
# |          LCL_STATIN|  biological process|  GO_0008150|
# |           LCL_NAIVE|immune system dis...| EFO_0000540|
# |                 LCL|immune system dis...| EFO_0000540|
# |       KIDNEY_CORTEX|urinary system di...| EFO_0009690|
# |       Kidney_Cortex|urinary system di...| EFO_0009690|
# |                IPSC|  biological process|  GO_0008150|
# |               ILEUM|gastrointestinal ...| EFO_0010282|
# |                 HLC|  biological process|  GO_0008150|
# |HIGH_GRADE_CARTIL...|musculoskeletal o...|OTAR_0000006|
# |HEART_LEFT_VENTRICLE|cardiovascular di...| EFO_0000319|
# |Heart_Left_Ventricle|cardiovascular di...| EFO_0000319|
# |HEART_ATRIAL_APPE...|cardiovascular di...| EFO_0000319|
# |Heart_Atrial_Appe...|cardiovascular di...| EFO_0000319|
# |          FIBROBLAST|musculoskeletal o...|OTAR_0000006|
# |                 FAT|musculoskeletal o...|OTAR_0000006|
# |ESOPHAGUS_MUSCULARIS|gastrointestinal ...| EFO_0010282|
# |Esophagus_Muscularis|gastrointestinal ...| EFO_0010282|
# |    ESOPHAGUS_MUCOSA|gastrointestinal ...| EFO_0010282|
# |    Esophagus_Mucosa|gastrointestinal ...| EFO_0010282|
# |       ESOPHAGUS_GEJ|gastrointestinal ...| EFO_0010282|
# |Esophagus_Gastroe...|gastrointestinal ...| EFO_0010282|
# |         DLPFC_NAIVE|nervous system di...| EFO_0000618|
# |    COLON_TRANSVERSE|gastrointestinal ...| EFO_0010282|
# |    Colon_Transverse|gastrointestinal ...| EFO_0010282|
# |       Colon_Sigmoid|gastrointestinal ...| EFO_0010282|
# |       COLON_SIGMOID|gastrointestinal ...| EFO_0010282|
# |Cells_EBV-transfo...|immune system dis...| EFO_0000540|
# |Cells_Cultured_fi...|  biological process|  GO_0008150|
# |    CD8_T-CELL_NAIVE|immune system dis...| EFO_0000540|
# |CD8_T-CELL_ANTI-C...|immune system dis...| EFO_0000540|
# |    CD4_T-CELL_NAIVE|immune system dis...| EFO_0000540|
# |CD4_T-CELL_ANTI-C...|immune system dis...| EFO_0000540|
# |Breast_Mammary_Ti...|reproductive syst...|OTAR_0000017|
# |              BREAST|reproductive syst...|OTAR_0000017|
# |Brain_Substantia_...|nervous system di...| EFO_0000618|
# |BRAIN_SUBSTANTIA_...|nervous system di...| EFO_0000618|
# |Brain_Spinal_cord...|nervous system di...| EFO_0000618|
# |   BRAIN_SPINAL_CORD|nervous system di...| EFO_0000618|
# |Brain_Putamen_bas...|nervous system di...| EFO_0000618|
# |       BRAIN_PUTAMEN|nervous system di...| EFO_0000618|
# |Brain_Nucleus_acc...|nervous system di...| EFO_0000618|
# |BRAIN_NUCLEUS_ACC...|nervous system di...| EFO_0000618|
# |         BRAIN_NAIVE|nervous system di...| EFO_0000618|
# |  BRAIN_HYPOTHALAMUS|nervous system di...| EFO_0000618|
# |  Brain_Hypothalamus|nervous system di...| EFO_0000618|
# |   Brain_Hippocampus|nervous system di...| EFO_0000618|
# |   BRAIN_HIPPOCAMPUS|nervous system di...| EFO_0000618|
# |Brain_Frontal_Cor...|nervous system di...| EFO_0000618|
# |BRAIN_FRONTAL_CORTEX|nervous system di...| EFO_0000618|
# |        BRAIN_CORTEX|nervous system di...| EFO_0000618|
# |        Brain_Cortex|nervous system di...| EFO_0000618|
# |    BRAIN_CEREBELLUM|nervous system di...| EFO_0000618|
# |    Brain_Cerebellum|nervous system di...| EFO_0000618|
# |Brain_Cerebellar_...|nervous system di...| EFO_0000618|
# |BRAIN_CEREBELLAR_...|nervous system di...| EFO_0000618|
# |Brain_Caudate_bas...|nervous system di...| EFO_0000618|
# |       BRAIN_CAUDATE|nervous system di...| EFO_0000618|
# |Brain_Anterior_ci...|nervous system di...| EFO_0000618|
# |BRAIN_ANTERIOR_CI...|nervous system di...| EFO_0000618|
# |      BRAIN_AMYGDALA|nervous system di...| EFO_0000618|
# |      Brain_Amygdala|nervous system di...| EFO_0000618|
# |               BRAIN|nervous system di...| EFO_0000618|
# |               BLOOD| hematologic disease| EFO_0005803|
# |        B-CELL_NAIVE|immune system dis...| EFO_0000540|
# |         B-CELL_CD19|immune system dis...| EFO_0000540|
# |       Artery_Tibial|cardiovascular di...| EFO_0000319|
# |       ARTERY_TIBIAL|cardiovascular di...| EFO_0000319|
# |     ARTERY_CORONARY|cardiovascular di...| EFO_0000319|
# |     Artery_Coronary|cardiovascular di...| EFO_0000319|
# |        Artery_Aorta|cardiovascular di...| EFO_0000319|
# |        ARTERY_AORTA|cardiovascular di...| EFO_0000319|
# |       ADRENAL_GLAND|endocrine system ...| EFO_0001379|
# |       Adrenal_Gland|endocrine system ...| EFO_0001379|
# |Adipose_Visceral_...|musculoskeletal o...|OTAR_0000006|
# |    ADIPOSE_VISCERAL|musculoskeletal o...|OTAR_0000006|
# |Adipose_Subcutaneous|musculoskeletal o...|OTAR_0000006|
# |ADIPOSE_SUBCUTANEOUS|musculoskeletal o...|OTAR_0000006|
# |       ADIPOSE_NAIVE|musculoskeletal o...|OTAR_0000006|
# +--------------------+--------------------+------------+

# %%
#### make format for left_locus and right locus in coloc 
## assessment of beta
## join biosamples with the phenotype 
coloc2 = coloc.select(
    F.concat_ws("_", "left_chrom", "left_pos", "left_ref", "left_alt").alias(
        "left_locus_id"
    ),
    F.concat_ws("_", "right_chrom", "right_pos", "right_ref", "right_alt").alias(
        "right_locus_id"
    ),
    F.col("left_study").alias("left_study_id"),
    F.col("right_study").alias("right_study_id"),
    "right_gene_id",
    "coloc_h4",
    "left_var_right_study_beta",
    F.col("left_type"),
    F.col("right_type"),
    F.col("right_bio_feature"),
    F.col("is_flipped"),
).withColumn(
    "beta_assessed",
    F.when(F.col("left_var_right_study_beta") > 0,
    F.lit("gof")).when(F.col("left_var_right_study_beta") < 0, F.lit("lof")).otherwise(F.lit("neutral"))
).join(samplesOnto,on=["right_bio_feature"],how="left")

# %%
### check for disparities using count of different assessment for beta for target

disparities=coloc2.groupBy("left_locus_id", "left_study_id", "right_gene_id"
    ).agg(
    F.size(F.collect_set("beta_assessed")).alias("count"),
)
### add the label of which left_locus_id,left_study_id and right_gene_id are having contradictions 

coloc3 = coloc2.join(
    disparities, on=["left_locus_id", "left_study_id", "right_gene_id"], how="left"
)

### dataset for focusing only in disparities using studiId and 
coloc4=coloc3.filter(F.col("count") > 1).groupBy(
    "left_locus_id", "left_study_id", "right_gene_id"
).agg(F.size(F.collect_set("right_study_id")),F.size(F.collect_set("right_bio_feature")))

# %%
## we should include the study right type because is the one that could give us contradictions
coloc3.filter((F.col("count") > 1) & (F.col("beta_assessed") != "neutral")).groupBy(
    "left_locus_id",
    "left_study_id",
    "right_gene_id",
    
    "right_study_id",
).pivot("beta_assessed").agg(
    F.collect_set("right_bio_feature").alias("tissues"),
    F.collect_set("therapyArea").alias("therArea"),
    F.size(F.collect_set("right_bio_feature")).alias("nr_tissues"),
).show(vertical=True, truncate=False)

### groupBy therapeutic area
###
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | Alasoo_2018
#  gof_tissues    | [MACROPHAGE_IFNG+SALMONELLA, MACROPHAGE_IFNG, MACROPHAGE_SALMONELLA, MACROPHAGE_NAIVE]
#  gof_therArea   | [immune system disease]
#  gof_nr_tissues | 4
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 1------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | BLUEPRINT
#  gof_tissues    | [T-CELL, NEUTROPHIL, MONOCYTE]
#  gof_therArea   | [immune system disease]
#  gof_nr_tissues | 3
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 2------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | BrainSeq
#  gof_tissues    | [BRAIN]
#  gof_therArea   | [nervous system disease]
#  gof_nr_tissues | 1
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 3------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | Braineac2
#  gof_tissues    | [PUTAMEN]
#  gof_therArea   | [nervous system disease]
#  gof_nr_tissues | 1
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 4------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | CEDAR
#  gof_tissues    | [ILEUM, NEUTROPHIL_CD15, RECTUM, B-CELL_CD19, MONOCYTE_CD14, T-CELL_CD8, T-CELL_CD4, TRANSVERSE_COLON]
#  gof_therArea   | [immune system disease, gastrointestinal disease]
#  gof_nr_tissues | 8
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 5------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | FUSION
#  gof_tissues    | [ADIPOSE_NAIVE, MUSCLE_NAIVE]
#  gof_therArea   | [musculoskeletal or connective tissue disease]
#  gof_nr_tissues | 2
# ...
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | Steinberg_2020
#  gof_tissues    | [SYNOVIUM_NAIVE, HIGH_GRADE_CARTILAGE_NAIVE, LOW_GRADE_CARTILAGE_NAIVE]
#  gof_therArea   | [musculoskeletal or connective tissue disease]
#  gof_nr_tissues | 3
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# -RECORD 19-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  left_locus_id  | 10_100152307_T_C
#  left_study_id  | GCST90025983
#  right_gene_id  | ENSG00000095485
#  right_study_id | TwinsUK
#  gof_tissues    | [FAT, SKIN, LCL, BLOOD]
#  gof_therArea   | [hematologic disease, musculoskeletal or connective tissue disease, immune system disease, integumentary system disease]
#  gof_nr_tissues | 4
#  lof_tissues    | []
#  lof_therArea   | []
#  lof_nr_tissues | 0
# only showing top 20 rows

# %%
coloc_study=coloc3.filter((F.col("count") > 1) & (F.col("beta_assessed") != "neutral")).groupBy(
    "left_locus_id",
    "left_study_id",
    "right_gene_id",
    #"right_study_id",
).pivot("beta_assessed").agg(
    F.collect_set("right_bio_feature").alias("tissues"),
    F.collect_set("therapyArea").alias("therArea"),
    F.size(F.collect_set("right_bio_feature")).alias("nr_tissues"),
    F.size(F.collect_set("therapyArea")).alias("nr_therArea"),
    F.countDistinct("right_study_id").alias("count_Studies")
).withColumn("therAreaOverlap", F.array_intersect(F.col("gof_therArea"),F.col("lof_therArea"))
).withColumn("nr_therAreaOverlap", F.size(F.array_intersect(F.col("gof_therArea"),F.col("lof_therArea")))).persist()

# %%
coloc_study.count()
# Out:
# 259827

# %%
coloc_study.groupBy("nr_therAreaOverlap").count().show()
# Out:
# +------------------+------+
# |nr_therAreaOverlap| count|
# +------------------+------+
# |                12|    81|
# |                 1| 71626|
# |                 6|  2246|
# |                 3|  7598|
# |                 5|  3031|
# |                 9|   738|
# |                 4|  5228|
# |                 8|  1148|
# |                 7|  1700|
# |                10|   453|
# |                11|   314|
# |                 2| 16867|
# |                 0|148777|
# |                13|    20|
# +------------------+------+

# %%
coloc3.select("right_study_id").distinct().count()
# Out:
# 38

# %%
coloc3.select("right_bio_feature").distinct().toPandas().to_csv("tissues_coloc.csv")

# %%
print((243220+16607)/666261)
# Out:
# 0.389977801492208

# %%
coloc3=coloc2.join(v2d_gwas.withColumnRenamed("study_id","left_study_id"), on=["left_locus_id","left_study_id"],how="left").persist()

# %%
coloc3.filter(F.col("is_flipped")=="true").show(truncate=False,vertical=True)
# Out:
# [Stage 42:>                                                         (0 + 1) / 1]
# -RECORD 0---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 1---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 2---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 3---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 4---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 5---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 6---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 7---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 8---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 9---------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 10--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 11--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 12--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 13--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 14--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 15--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 16--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 17--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 18--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# -RECORD 19--------------------------------------------
#  left_locus_id             | 10_100152307_T_C
#  left_study_id             | GCST90025955
#  right_locus_id            | 10_100129660_T_C
#  right_study_id            | GTEx-sQTL
#  right_gene_id             | ENSG00000155287
#  coloc_h4                  | 0.9678297263356717
#  left_var_right_study_beta | -0.4308566451072693
#  left_type                 | gwas
#  right_type                | sqtl
#  right_bio_feature         | Brain_Cortex
#  is_flipped                | true
#  beta                      | 0.0280807
#  odds_ratio                | null
#  trait_reported            | Apolipoprotein A1 levels
#  trait_efos                | [EFO_0004614]
#  n_cases                   | null
#  n_initial                 | 398508
# only showing top 20 rows

# %%
coloc3.groupBy("left_locus_id","right_locus_id","left_study_id").agg(F.countDistinct("right_gene_id").alias("count")).sort(F.col("count").desc()).show()
# Out:
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_27 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_7 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_95 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_121 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_197 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_91 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_81 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_160 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_116 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_54 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_40 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_43 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_44 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_126 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_156 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_51 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_76 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_79 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_131 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_17 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_71 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_122 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_146 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_77 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_62 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_98 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_108 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_50 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_153 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_179 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_163 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_99 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_39 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_132 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_90 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_23 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_92 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_112_0 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_150 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_3 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_180 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_172 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_130 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_83 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_16 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_67 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_87 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_142 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_176 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_185 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_32 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_5 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_26 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_72 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_147 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_56 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_123 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_171 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_45 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_127 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_11 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_191 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_57 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_35 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_169 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_28 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_31 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_52 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_36 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_74 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_162 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_105 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_129 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_148 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_30 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_167 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_117 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_21 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_34 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_190 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_84 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_89 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_155 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_159 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_103 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_141 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_109 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_100 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_46 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_82 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_158 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_154 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_194 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_128 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_37 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_48 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_66 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_9 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_149 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_49 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_157 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_41 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_101 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_25 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_63 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_0 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_78 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_61 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_140 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_93 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_13 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_80 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_59 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_119 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_1 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_55 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_85 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_97 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_184 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_115 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_187 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_19 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_196 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_58 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_65 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_38 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_174 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_136 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_189 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_198 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_6 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_175 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_137 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_20 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_195 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_151 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_22 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_69 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_2 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_144 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_161 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_64 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_177 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_4 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_68 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_12 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_10 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_183 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_143 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_186 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_138 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_53 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_70 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_192 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_193 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_139 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_42 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_73 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_168 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_170 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_188 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_33 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_178 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_164 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_181 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_60 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_47 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_152 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_18 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_24 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_165 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_29 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_14 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_145 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_199 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_88 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_8 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_15 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_75 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_182 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_166 !
# 23/09/14 10:43:09 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_155_173 !
# 23/09/14 10:43:10 WARN YarnAllocator: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN YarnAllocator: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 8 for reason Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 ERROR YarnScheduler: Lost executor 8 on jr-doe-m.c.open-targets-eu-dev.internal: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 7 for reason Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 104.0 in stage 54.0 (TID 618) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 110.0 in stage 54.0 (TID 621) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 96.0 in stage 54.0 (TID 615) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 112.0 in stage 54.0 (TID 623) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 118.0 in stage 54.0 (TID 626) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 107.0 in stage 54.0 (TID 620) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 94.0 in stage 54.0 (TID 614) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 106.0 in stage 54.0 (TID 619) (jr-doe-m.c.open-targets-eu-dev.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000008 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 ERROR YarnScheduler: Lost executor 7 on jr-doe-m.c.open-targets-eu-dev.internal: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 84.0 in stage 54.0 (TID 609) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 113.0 in stage 54.0 (TID 624) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 102.0 in stage 54.0 (TID 617) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 111.0 in stage 54.0 (TID 622) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 89.0 in stage 54.0 (TID 613) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 100.0 in stage 54.0 (TID 616) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 114.0 in stage 54.0 (TID 625) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# 23/09/14 10:43:10 WARN TaskSetManager: Lost task 86.0 in stage 54.0 (TID 610) (jr-doe-m.c.open-targets-eu-dev.internal executor 7): ExecutorLostFailure (executor 7 exited caused by one of the running tasks) Reason: Container from a bad node: container_1694681996867_0001_01_000007 on host: jr-doe-m.c.open-targets-eu-dev.internal. Exit status: 137. Diagnostics: [2023-09-14 10:43:09.840]Container killed on request. Exit code is 137
# [2023-09-14 10:43:09.840]Container exited with a non-zero exit code 137.
# [2023-09-14 10:43:09.840]Killed by external signal
# .
# ERROR:root:KeyboardInterrupt while sending command.=========>  (190 + 10) / 200]
# Traceback (most recent call last):
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/miniconda3/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7654/2762734788.py in <cell line: 1>()
# ----> 1 coloc3.groupBy("left_locus_id","right_locus_id","left_study_id").agg(F.countDistinct("right_gene_id").alias("count")).sort(F.col("count").desc()).show()
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     604
#     605         if isinstance(truncate, bool) and truncate:
# --> 606             print(self._jdf.showString(n, 20, vertical))
#     607         else:
#     608             try:
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/lib/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/miniconda3/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 54:====================================================> (194 + 6) / 200]
